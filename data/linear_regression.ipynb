# %%
import pandas as pd
import numpy as np
import sklearn
from textgenrnn import textgenrnn
import emoji
from sklearn.linear_model import LogisticRegression
import re

# %%
def alias_translator(aliases):
	results = []
	BASE = ":"

	for alias in aliases:
		emo_boi = emoji.emojize(BASE + alias + BASE)
		results.append(emo_boi)
	return results

def emoji_counter(clean):
	ALCOHOL_ALIAS = ["tropical_drink", "wine_glass", "beer", "cocktail", "beers", "sake"]
	DRUG_ALIAS = ["smoking", "no_smoking", "pill", "dash", "leaves", "mushroom", "ear_of_rice"]
	alcohol_emojis = alias_translator(ALCOHOL_ALIAS)
	drug_emojis = alias_translator(DRUG_ALIAS)
	ILLICIT_EMOJIS = alcohol_emojis + drug_emojis
	count = 0
	for character in clean:
		if character in ILLICIT_EMOJIS:
			count += 1
	return count

def phrase_counter(clean):
	ALCOHOL_PHRASES = ["alc", "alcohol", "bubbly", "champagne", "drinks", "beer", "bud", "drank"]
	DRUG_PHRASES = ["weed", "pills", "ecstasy", "broccoli", "plug", "codeine", 
	"high", "buzzed", "stoned", "420", "smoke", "popper"]
	VAPE_PHRASES = ["pods", "pod", "juul", "suorin", "vape", "vaping", "vape"]
	BAD_BOIS = ALCOHOL_PHRASES + DRUG_PHRASES + VAPE_PHRASES
	count = 0 
	for word in clean:
		if word in BAD_BOIS:
			count += 1

	return count

# %%
df = pd.read_csv("train_test_data.csv")

# %%
df.tail()
# Out:
#                                          payment_text  label
# 94                                      Mountain food      0
# 95  you are the bestest person ever and I apprecia...      0
# 96                        you’re doing great sweetie🥂      0
# 97                   I never paid you for gum yikenss      0
# 98                                             hi hey      0

# %%
def text_cleaner(dirty):
    clean = dirty.lower()
    return clean

# returns X_train, X_test, y_train, y_test
def pipeline(df):
    df["payment_text"] = df["payment_text"].apply(text_cleaner)
    df["emojis"] = df["payment_text"].apply(str.split).apply(emoji_counter)
    df["bad_phrases"] = df["payment_text"].apply(str.split).apply(phrase_counter)
    Y = df["label"]
    X = df[["emojis", "bad_phrases"]]
    return sklearn.model_selection.train_test_split(X, Y, test_size = 0.33)

# %%
def create_more(text_file):
    textgen = textgenrnn()
    textgen.train_from_file(text_file, num_epochs=10)
    return textgen.generate(5)

# %%
create_more('clean.txt')
# Out:
# 48 texts collected.
# Training on 998 character sequences.
# Epoch 1/10
# 7/7 [==============================] - 3s 370ms/step - loss: 2.6060
# ####################
# Temperature: 0.2
# ####################
# I makiki bumbbie pro money person position but but bust intelding bust but housh bump you fool my bust but hey hell some pal bent bust the person pett
#
# The budge fool mod
#
# The budge but bust white
#
# ####################
# Temperature: 0.5
# ####################
# empty solving run of some Of y
#
# Fook of my the plant
#
# No food my bust my my buddie past
#
# ####################
# Temperature: 1.0
# ####################
# My googioo
#
# d my bud iftiest on you white
#
# Bbiti the tuthe the bumbbook
#
# Epoch 2/10
# 7/7 [==============================] - 1s 206ms/step - loss: 1.6924
# ####################
# Temperature: 0.2
# ####################
# The brook
#
# The sounddenoum of 1000
#
# Appliviation but I’m deposit
#
# ####################
# Temperature: 0.5
# ####################
# The weekly grend heals and peace I’m so so so so so so so so so so so so so so so so so so so so so so so so so so mur mark
#
# New porn power food
#
# I watch my brother making me for a so food
#
# ####################
# Temperature: 1.0
# ####################
# The sweetie
#
# Appy
#
# Apabling. Thank you!
#
# Epoch 3/10
# 7/7 [==============================] - 2s 218ms/step - loss: 1.1564
# ####################
# Temperature: 0.2
# ####################
# The burrites of a sambed
#
# The bestest person how much bust so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so
#
# The bestest person at a bike
#
# ####################
# Temperature: 0.5
# ####################
# A bust and ever paid
#
# The burritest and I appreciate you so so so so so so so so so so so so seatest some paid how much house her making some panchoola gum so so so so so you’re so much in my person hashest and I assort me of a space
#
# so how much of sexu bust
#
# ####################
# Temperature: 1.0
# ####################
# Commution Up a basebut etclyi ok. :)
#
# Think
#
# 7
#
# Epoch 4/10
# 7/7 [==============================] - 2s 238ms/step - loss: 0.8827
# ####################
# Temperature: 0.2
# ####################
# Concert
#
# The bestest person at a solving the month
#
# The bestest person at a solving the google person at a sweetie problem
#
# ####################
# Temperature: 0.5
# ####################
# my hurion paid and some panch of 1000
#
# Another person sam my lifeer yest yest
#
# of anime gumabity
#
# ####################
# Temperature: 1.0
# ####################
# Jumor bust get my account
#
#
#
# my girly ride of sweetie
#
# Epoch 5/10
# 7/7 [==============================] - 2s 246ms/step - loss: 0.7560
# ####################
# Temperature: 0.2
# ####################
# For solving the bestes to maki a burs
#
# The bestest paid you hashest
#
# The bestest paid you hashest
#
# ####################
# Temperature: 0.5
# ####################
# gummy panch money and ever saladdd
#
# For solving the groundd
#
# Jump The bestest pictures storm-Ron teachmon serionariol money for solving the river
#
# ####################
# Temperature: 1.0
# ####################
#
#
# Mountain food
#
# Test on rat
#
# Epoch 6/10
# 7/7 [==============================] - 2s 254ms/step - loss: 0.6488
# ####################
# Temperature: 0.2
# ####################
# For solving the great sisterfly
#
# The burrito a bike
#
# Application fee  for solving the bestest paid you for solving the great for solving the great great for solving the great for solving the google please rent and peace of mind
#
# ####################
# Temperature: 0.5
# ####################
# How did maki money for solving the oriat
#
# For money for gum
#
# The burrito an aptriative bust
#
# ####################
# Temperature: 1.0
# ####################
# mistakes hey paid
#
# me wales for solving that mushlif he’s appure
#
# Ever bestec you asiis... :)
#
# Epoch 7/10
# 7/7 [==============================] - 2s 246ms/step - loss: 0.5848
# ####################
# Temperature: 0.2
# ####################
# Mountain food
#
# The bestest paid you for 1000
#
# For solving the great for solving the great for 1000
#
# ####################
# Temperature: 0.5
# ####################
# Notebook
#
# Flex   and ever wrong great for solving the bestest plant ever ever and ever sweetiess and some paid you for teaching me and some panch international saladdd
#
# Festivity
#
# ####################
# Temperature: 1.0
# ####################
# bustball baseball problem
#
# How did the mild person haha picturess bro intern weekly.
#
# browz
#
# Epoch 8/10
# 7/7 [==============================] - 2s 340ms/step - loss: 0.5273
# ####################
# Temperature: 0.2
# ####################
# The burrito I’m sorry
#
# For saving my life
#
# For saving my life
#
# ####################
# Temperature: 0.5
# ####################
# Rental for solving the bestest
#
# Because I'm dumb
#
# For saving my life
#
# ####################
# Temperature: 1.0
# ####################
# ewate of mint
#
# you’re did tie massagery
#
# 1/3 problem :  so file how to vidual
#
# Epoch 9/10
# 7/7 [==============================] - 2s 348ms/step - loss: 0.4954
# ####################
# Temperature: 0.2
# ####################
# For saving my life
#
# For person haha paid you said
#
# For saving my life
#
# ####################
# Temperature: 0.5
# ####################
# Flex   Game Test of About Paid It The bestest Paid
#
# The burrito the browz
#
#  for solving the google ever prize money security
#
# ####################
# Temperature: 1.0
# ####################
# me bud peace of mind of my here making great for fectiona
#
# :)
#
# Notebook facts...
#
# Epoch 10/10
# 7/7 [==============================] - 2s 305ms/step - loss: 0.4683
# ####################
# Temperature: 0.2
# ####################
# For saving my life
#
#
#
# For solving the bestest   person and I appreciate you so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so so
#
# ####################
# Temperature: 0.5
# ####################
# white bestest yesting and I appreciate you weekly
#
# Application fee
#
# Flex   exam :)
#
# ####################
# Temperature: 1.0
# ####################
# 1/3 of a work
#
# duvk y oths
#   0%|          | 0/5 [00:00<?, ?it/s]
# Taken encer problem
#  40%|████      | 2/5 [00:00<00:00,  3.55it/s]
# Empt the bestest person
#
# The browz
#  60%|██████    | 3/5 [00:00<00:00,  4.17it/s]
# of a bike
#  80%|████████  | 4/5 [00:01<00:00,  3.27it/s]
# out of a wein paid you for 1 month
# 100%|██████████| 5/5 [00:01<00:00,  3.39it/s]
# Rental for 1.5 month

# %%
create_more('illicit.txt')
# Out:
# 49 texts collected.
# Training on 774 character sequences.
# Epoch 1/10
# 6/6 [==============================] - 3s 485ms/step - loss: 2.7629
# ####################
# Temperature: 0.2
# ####################
# Brown drank
#
# Berder for the gradk
#
# Brown drank
#
# ####################
# Temperature: 0.5
# ####################
# Gribstend drank
#
# rolling and drank
#
# Brand those pills
#
# ####################
# Temperature: 1.0
# ####################
# reink
#
# Bed for bedrock
#
# i bostur_ weed in the dandy drank
#
# Epoch 2/10
# 6/6 [==============================] - 2s 263ms/step - loss: 1.6603
# ####################
# Temperature: 0.2
# ####################
# Strippers
#
# Banks and uber drank
#
# Strippers
#
# ####################
# Temperature: 0.5
# ####################
# Herb
#
# God per dog stuff
#
# Drank to drank in the drank in the first drank
#
# ####################
# Temperature: 1.0
# ####################
# [f]
#
# card daughters aboud bakog and me fougrabor user to weed is this eigners
#
# the weed drank
#
# Epoch 3/10
# 6/6 [==============================] - 2s 266ms/step - loss: 1.1253
# ####################
# Temperature: 0.2
# ####################
# Weed for the good stuff
#
#
#
# Weed drank
#
# ####################
# Temperature: 0.5
# ####################
# Champagne & Stuff and import
#
# Weed and uber drank
#
# pods drank & drank
#
# ####################
# Temperature: 1.0
# ####################
# Tool Uber drank
#
# Strop bank
#
# pills - usaffl han per poopar monter
#
# Epoch 4/10
# 6/6 [==============================] - 2s 278ms/step - loss: 0.8451
# ####################
# Temperature: 0.2
# ####################
# I drank while you were ssugners
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#
#
# Alcccc
#
# Steroids
#
# ####################
# Temperature: 1.0
# ####################
# EA & 4, roller sales
#
# stummers
#
# Strippers when I drad pee weed up
#
# Epoch 5/10
# 6/6 [==============================] - 2s 254ms/step - loss: 0.7121
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
# Bedrans of the drug strip
#
# har
#
# Chindotweod
#
# Epoch 6/10
# 6/6 [==============================] - 2s 291ms/step - loss: 0.5874
# ####################
# Temperature: 0.2
# ####################
# Weed and uber
#
# Strippers
#
#
#
# ####################
# Temperature: 0.5
# ####################
# Drank
#
# I’m so sorry i drank while you were sleeping
#
# Weed and uber
#
# ####################
# Temperature: 1.0
# ####################
# poppers
#
# Uber
#
# erh.
#
# Epoch 7/10
# 6/6 [==============================] - 2s 301ms/step - loss: 0.5493
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# Mac and drank
#
# Here is the 20 im obligated to donate as weed grass trees
#
#
#
# ####################
# Temperature: 1.0
# ####################
# It’s permarrased
#
# pee weed - 4k drank
#
# Weed the good stuff
#
# Epoch 8/10
# 6/6 [==============================] - 2s 274ms/step - loss: 0.5499
# ####################
# Temperature: 0.2
# ####################
# Here is the 20 im obligated to donate as weed weed drank
#
#
#
# Crack and ammo
#
# ####################
# Temperature: 0.5
# ####################
#
#
# poppers and ammo
#
# Thanks for the good stuff
#
# ####################
# Temperature: 1.0
# ####################
# Thanks for normes
#
# drank
#
# Crack and amn
#
# Epoch 9/10
# 6/6 [==============================] - 2s 260ms/step - loss: 0.4772
# ####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 1.0
# ####################
# Alcc
#
# Throgs gods
#
# Alcccc
#
# Epoch 10/10
# 6/6 [==============================] - 2s 273ms/step - loss: 0.4607
# ####################
# Temperature: 0.2
# ####################
# Strippers
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
#
#
# Bad things
#
# pods and alc
#
# ####################
# Temperature: 1.0
# ####################
# ️
#   0%|          | 0/5 [00:00<?, ?it/s]
# The Heroid drank
#
# Drank
#  20%|██        | 1/5 [00:00<00:02,  1.98it/s]
# Pour up, weed anole and notess
#
# drank
#  60%|██████    | 3/5 [00:00<00:00,  2.56it/s]
# Strippers
# 100%|██████████| 5/5 [00:01<00:00,  3.10it/s]
# pods and alc & Strippers
#
# Palm trees

# %%
def tokenize(sentences):
    words = []
    for sentence in sentences:
        w = word_extraction(sentence)
        words.extend(w)
        
    words = sorted(list(set(words)))
    return words

def word_extraction(sentence):
    ignore = ['a', "the", "is"]
    words = re.sub("[^\w]", " ",  sentence).split()
    cleaned_text = [w.lower() for w in words if w not in ignore]
    return cleaned_text    
    
def generate_bow(allsentences):    
    vocab = tokenize(allsentences)
    print("Word List for Document \n{0} \n".format(vocab));

    for sentence in allsentences:
        words = word_extraction(sentence)
        bag_vector = np.zeros(len(vocab))
        for w in words:
            for i,word in enumerate(vocab):
                if word == w: 
                    bag_vector[i] += 1
